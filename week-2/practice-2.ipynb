# %%
# prcatice-2/cell-1
# pyhon program to swap two cities

city_1 = input("Enter name of City 1: ")
city_2 = input("Enter name of City 2: ")

# create a temporary variable and swap the cities 
temp = city_1
city_1 = city_2
city_2 = temp

print(f"The name of City 1 after swapping is {city_1}")
print(f"The name of City 2 after swapping is {city_2}")
# Out:
# Enter name of City 1:  Zaria
# Enter name of City 2:  Paris
# The name of City 1 after swapping is Paris
# The name of City 2 after swapping is Zaria

# %%
# practice-2/cell-2
# program to if a number is positive, Negative or 0

num = float(input("Enter a number: "))
if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative")
# Out:
# Enter a number:  -4
# Negative

# %%
# practice-2/cell-3
# COUPE DE ESCRIVA 2023: FOOTBALL PICKS

print("Welcome to COUPE DE ESCRIVA 2023: FOOTBALL PICKS \n")
captain = {'Madiba': 'Chubby Obiora-Okafo', 'Blue-Jays': 'Christofer Uweh', 'Cirok': 'alexander',
          'TSG Walkers': 'Ikechuku'}

goalkeepers = {'Madiba': 'Chubby Obiora-Okafo', 'Blue-Jays': 'Oladimeji Abaniwondea/Jeffery Awagu',
'Cirok': 'Timileyin Pearse/lzuako Jeremy', 'TSG walkers': 'Ayomide Ojituku' }

for pick in captain:
    print(pick, captain[pick])
print('\n')

for pick in goalkeepers:
    print(pick, goalkeepers[pick])
# Out:
# Welcome to COUPE DE ESCRIVA 2023: FOOTBALL PICKS
#
# Madiba Chubby Obiora-Okafo
# Blue-Jays Christofer Uweh
# Cirok alexander
# TSG Walkers Ikechuku
#
#
# Madiba Chubby Obiora-Okafo
# Blue-Jays Oladimeji Abaniwondea/Jeffery Awagu
# Cirok Timileyin Pearse/lzuako Jeremy
# TSG walkers Ayomide Ojituku
