# %% [markdown]
# A) Pseudocode for the store checkout
#
# BEGIN
# Want to check out?
#
# if yes
#
# Display the price of the item
#
# INPUT the amount
#
# SELECT payment method
#
# COMPUTE the payment
#
# Confirm the payment
#
# If payment succeeded
#
# PRINT reciept
#
# ELIF
#
# PRINT again
#
# ELIF you don't want to check out
#
# END

# %% [markdown]
# Flowchart for the store checkout
#
# ![Check_out_flowchart.drawio.png](attachment:d6fea3f5-44f6-4279-a04b-bce68301f04a.png)

# %% [markdown]
# B) Morning Routine
# ![Morning_routine.drawio (2).png](attachment:2d4694a3-6e4e-421b-9ed7-8cb451fce5e0.png)

# %% [markdown]
# C) An Algorithm to take two names with ages and swap the ages
# ![Name_age.drawio.png](attachment:d7bcc2c5-1be0-4499-8e08-d0048883032a.png)
