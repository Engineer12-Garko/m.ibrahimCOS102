# %%
# Practice 1 | cell 1 My first calss


class SST:
    prog1 = 'Software Engineering' # class variable

    def __init__(self, name):
        self.name =  name # insatance variable
    def speak(self):
        print('\nMy name is ', self.name)
        print('I studey ', SST.prog1)



stud1 = SST(input('Enter student 1 name: '))
stud2 = SST(input('Enter student 2 name: '))



stud1.speak()
stud2.speak()
# Out:
# Enter student 1 name:  Moses Musa
# Enter student 2 name:  Mubarak Ali
# My name is  Moses Musa
# I studey  Software Engineering
#
# My name is  Mubarak Ali
# I studey  Software Engineering

# %%
class Addition:
    def __init__(self, f, s):
        self.first = f
        self.second = s
        self.answer = None

    def calculate(self):
       self.answer = self.first + self.second

    def display(self):
       print('\nFisrt: " ', self.first)
       print('\nSecond: " ', self.second)
       print('\nSum: " ', self.answer)
       

num1 = int(input('Enter Fisrt number: '))
num2 = int(input('Enter Second number: '))

obj = Addition(num1, num2)
# obj.calculate()
obj.display()
obj.calculate()
# Out:
# Enter Fisrt number:  45
# Enter Second number:  56
# Fisrt: "  45
#
# Second: "  56
#
# Sum: "  None
