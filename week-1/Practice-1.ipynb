# %%
# Practice-1
# integer number
num = 100
print(num)
print('Data Type of nun is ',type(num))

# float number 
fnum = 34.45
print(fnum)
print('Data Type of fnun is ',type(fnum))

# complex number 
cnum = 3 + 4j
print(cnum)
print('Data Type of cnun is ',type(cnum))
# Out:
# 100
# Data Type of nun is  <class 'int'>
# 34.45
# Data Type of fnun is  <class 'float'>
# (3+4j)
# Data Type of cnun is  <class 'complex'>

# %%
#
